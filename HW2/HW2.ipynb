# %%
import pandas as pd
import altair as alt

# %% [markdown]
# - Як змінювалась структура генерації електроенергії за роками?
#
# - Як залежить споживання електроенергії від дня року та години доби?
#
# - Як змінюється генерація електроенергії з різних джерел впродовж доби?
#
# - Як змінюється споживання електроенергії впродовж доби у розрізі місяців року та пір року?
#
# - Як змінюється споживання електроенергії впродовж тижня?

# %%
df = pd.read_excel('2014-2020.xlsx')
df["Total"] = df["AES"]+df["TES"]+df["VDE"]+df["TEC"]+df["GES"]+df["GAES_GEN"]
df
# Out:
#             Час/Дата    AES   TEC  VDE   TES     GES  GAES_GEN  CONSUMPTION  \
# 0      24-31.12.2020   9235  2039  621  4942   385.0         0        16693
# 1      23-31.12.2020   9221  2159  707  5549   470.0         0        17805
# 2      22-31.12.2020   9249  2377  709  5906  1000.0         0        18870
# 3      21-31.12.2020   9256  2499  702  6329   909.0       322        19887
# 4      20-31.12.2020   9213  2521  702  6640   823.0       602        20387
# ...              ...    ...   ...  ...   ...     ...       ...          ...
# 61363   5-01.01.2014  10427  2826   49  5506   274.0         0        18072
# 61364   4-01.01.2014  10475  2827   42  5524   185.0         0        18453
# 61365   3-01.01.2014  10515  2837   54  5865   355.0         0        19107
# 61366   2-01.01.2014  10606  2822   49  6038   863.0         0        19665
# 61367   1-01.01.2014  10728  2825   50  6044  1809.0         0        20586
#
#        GAES_PUMP  UK_BLR_RUS  UK_EURO  UK_MLD  Unnamed: 12    Total
# 0         -405.0       -84.0    -11.0   -29.0          NaN  17222.0
# 1            0.0       -43.0   -212.0   -46.0          NaN  18106.0
# 2            0.0       -13.0   -328.0   -30.0          NaN  19241.0
# 3            0.0         0.0    -64.0   -66.0          NaN  20017.0
# 4            0.0       -29.0    -48.0   -37.0          NaN  20501.0
# ...          ...         ...      ...     ...          ...      ...
# 61363     -488.0       -90.0   -421.0   -11.0          NaN  19082.0
# 61364        0.0      -175.0   -399.0   -26.0          NaN  19053.0
# 61365        0.0       -59.0   -400.0   -60.0          NaN  19626.0
# 61366        0.0      -200.0   -409.0  -104.0          NaN  20378.0
# 61367        0.0      -365.0   -355.0  -150.0          0.0  21456.0
#
# [61368 rows x 14 columns]

# %% [markdown]
# - Як змінювалась структура генерації електроенергії за роками?

# %%
df['Hour'] = [date.split("-")[0] for date in df["Час/Дата"]]
df['Date'] = [date.split("-")[1].replace(".","-") for date in df["Час/Дата"]]

df["Hour"], df["Date"]
# Out:
# (0        24
#  1        23
#  2        22
#  3        21
#  4        20
#           ..
#  61363     5
#  61364     4
#  61365     3
#  61366     2
#  61367     1
#  Name: Hour, Length: 61368, dtype: object,
#  0        31-12-2020
#  1        31-12-2020
#  2        31-12-2020
#  3        31-12-2020
#  4        31-12-2020
#              ...
#  61363    01-01-2014
#  61364    01-01-2014
#  61365    01-01-2014
#  61366    01-01-2014
#  61367    01-01-2014
#  Name: Date, Length: 61368, dtype: object)

# %%
# df_date = 
df[["Date", "Total"]].groupby(df["Date"]).sum()
# df_date
# Out:
#                Total
# Date
# 01-01-2014  499560.0
# 01-01-2015  506955.0
# 01-01-2016  437352.0
# 01-01-2017  440731.0
# 01-01-2018  396317.0
# ...              ...
# 31-12-2016  479534.0
# 31-12-2017  444767.0
# 31-12-2018  466325.0
# 31-12-2019  446378.0
# 31-12-2020  451512.0
#
# [2557 rows x 1 columns]

# %% [markdown]
# Як залежить споживання електроенергії від дня року та години доби?

# %%
alt.Chart(df_date).mark_point().encode(
    y = alt.Y('Total:Q'),
    x = alt.X('Date', type="temporal"),
).properties(width = 950, height = 500)
# Out:
# alt.Chart(...)

# %%
df["Date"][:100]
# Out:
# 0     31-12-2020
# 1     31-12-2020
# 2     31-12-2020
# 3     31-12-2020
# 4     31-12-2020
#          ...
# 95    28-12-2020
# 96    27-12-2020
# 97    27-12-2020
# 98    27-12-2020
# 99    27-12-2020
# Name: Date, Length: 100, dtype: object

# %% [markdown]
# Як змінюється генерація електроенергії з різних джерел впродовж доби?
